# %%
# !cd..

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 9E09-C7C1
#
#  C:\Users\user\python programming\0602_데이터수집 디렉터리
#
# 2021-06-03  오후 02:57    <DIR>          .
# 2021-06-03  오후 02:57    <DIR>          ..
# 2021-06-03  오후 02:54    <DIR>          .ipynb_checkpoints
# 2021-06-03  오전 11:47            25,532 01_tripadvisor_crawling_class-Copy1.ipynb
# 2021-06-03  오전 11:47            25,532 01_tripadvisor_crawling_class.ipynb
# 2021-06-03  오전 10:08           728,046 02_coupang_class.ipynb
# 2021-06-03  오후 01:18            32,105 03_tripadvisor_image_crawling_by_selenium_class.ipynb
# 2021-06-03  오후 12:18    <DIR>          busan_img
# 2021-06-03  오전 10:58        11,084,800 chromedriver.exe
# 2021-06-03  오전 09:01             2,462 coupang_kimch.csv
# 2021-06-03  오전 11:55    <DIR>          img
# 2021-06-03  오후 02:57            10,577 Untitled.ipynb
#                7개 파일          11,909,054 바이트
#                5개 디렉터리  178,881,630,208 바이트 남음

# %%
import pandas as pd
csv_test = pd.read_csv('games.csv')

# %%
csv_test
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...
