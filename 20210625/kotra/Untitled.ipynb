# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
trade_df = pd.read_csv('Train_KOTRA_0525.csv')

# %%
trade_df.head(1)
# Out:
#    UNC_YEAR    HSCD  COUNTRYCD COUNTRYNM  TRADE_COUNTRYCD   TRADE_HSCD  \
# 0      2017  190590         12   Algeria      46052990973  19480986257
#
#    TARIFF_AVG       SNDIST  NY_GDP_MKTP_CD  NY_GDP_MKTP_CD_1Y  SP_POP_TOTL  \
# 0        30.0  3878.238437    170163165961       159994837855     41389198
#
#    PA_NUS_FCRF  IC_BUS_EASE_DFRN_DB       KMDIST  TRADE_HSCD_COUNTRYCD  \
# 0   110.973017             46.10981  9954.009766             3416326.0
#
#    KR_TRADE_HSCD_COUNTRYCD
# 0                     7657

# %%
trade_df.columns=['기준연도', '품목코드', '국가코드', '국가명', '국가 전체 품목 수입금액', '해당 품목 전세계 총 수입금액','해당 국가 해당 품목 관세율', '수입국가 간 평균 거리','GDP', '이전 GDP', '인구', '공식환율', '비즈니스 용이성점수', '해당 국가와 한국과의 거리','해당 연도 해당 국가의 해당 품목 수입금액', '내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액']

# %%
trade_df.head(1)
# Out:
#    기준연도    품목코드  국가코드      국가명  국가 전체 품목 수입금액  해당 품목 전세계 총 수입금액  \
# 0  2017  190590    12  Algeria    46052990973       19480986257
#
#    해당 국가 해당 품목 관세율  수입국가 간 평균 거리           GDP        이전 GDP        인구  \
# 0             30.0   3878.238437  170163165961  159994837855  41389198
#
#          공식환율  비즈니스 용이성점수  해당 국가와 한국과의 거리  해당 연도 해당 국가의 해당 품목 수입금액  \
# 0  110.973017    46.10981     9954.009766                3416326.0
#
#    내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액
# 0                            7657

# %%
trade_df.dtypes
# Out:
# 기준연도                                int64
# 품목코드                                int64
# 국가코드                                int64
# 국가명                                object
# 국가 전체 품목 수입금액                       int64
# 해당 품목 전세계 총 수입금액                    int64
# 해당 국가 해당 품목 관세율                   float64
# 수입국가 간 평균 거리                      float64
# GDP                                 int64
# 이전 GDP                              int64
# 인구                                  int64
# 공식환율                              float64
# 비즈니스 용이성점수                        float64
# 해당 국가와 한국과의 거리                    float64
# 해당 연도 해당 국가의 해당 품목 수입금액           float64
# 내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액      int64
# dtype: object

# %%
trade_df['공식환율']=trade_df['공식환율'].fillna(1.1390)

# %%
trade_df.head(1)
# 유로존 국가 결측치를 유로로 채웠음
# Out:
#    기준연도    품목코드  국가코드      국가명  국가 전체 품목 수입금액  해당 품목 전세계 총 수입금액  \
# 0  2017  190590    12  Algeria    46052990973       19480986257
#
#    해당 국가 해당 품목 관세율  수입국가 간 평균 거리           GDP        이전 GDP        인구  \
# 0             30.0   3878.238437  170163165961  159994837855  41389198
#
#          공식환율  비즈니스 용이성점수  해당 국가와 한국과의 거리  해당 연도 해당 국가의 해당 품목 수입금액  \
# 0  110.973017    46.10981     9954.009766                3416326.0
#
#    내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액
# 0                            7657

# %%
trade_df.isna().sum()
# Out:
# 기준연도                                0
# 품목코드                                0
# 국가코드                                0
# 국가명                                 0
# 국가 전체 품목 수입금액                       0
# 해당 품목 전세계 총 수입금액                    0
# 해당 국가 해당 품목 관세율                   129
# 수입국가 간 평균 거리                       22
# GDP                                 0
# 이전 GDP                              0
# 인구                                  0
# 공식환율                                0
# 비즈니스 용이성점수                          0
# 해당 국가와 한국과의 거리                      0
# 해당 연도 해당 국가의 해당 품목 수입금액            21
# 내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액      0
# dtype: int64

# %%
trade_df[trade_df['해당 연도 해당 국가의 해당 품목 수입금액'].isna()]
# Out:
#        기준연도    품목코드  국가코드                   국가명  국가 전체 품목 수입금액  \
# 20     2017  190590   414                Kuwait    33568329846
# 62     2017  190230   414                Kuwait    33568329846
# 105    2017  190219   414                Kuwait    33568329846
# 269    2017  540769   344  China, Hong Kong SAR   589317409641
# 486    2017  210690   414                Kuwait    33568329846
# 529    2017  210390   414                Kuwait    33568329846
# 1090   2017  481890   682          Saudi Arabia   134519106951
# 10247  2017  600410   364                  Iran    51612276867
# 13068  2017  852692   826        United Kingdom   641332371112
# 21125  2017  382499   484                Mexico   420369113272
# 21131  2017  382499   608           Philippines   101889431966
# 21134  2017  382499   682          Saudi Arabia   134519106951
# 21136  2017  382499   702             Singapore   327709659599
# 21137  2017  382499   704              Viet Nam   213215271369
# ...

# %%
len(trade_df['품목코드'].unique())

# %%
a = trade_df[trade_df['해당 국가 해당 품목 관세율'].isnull()]['품목코드'].unique()

# %%
a

# %%
a = list(a)

# %%
print(len(trade_df[trade_df['품목코드']==420232]))
print(len(trade_df[trade_df['품목코드']==999999]))
print(len(trade_df[trade_df['품목코드']==903300]))
print(len(trade_df[trade_df['품목코드']==903290]))
print(len(trade_df[trade_df['품목코드']==903190]))
print(len(trade_df[trade_df['품목코드']==902690]))
print(len(trade_df[trade_df['품목코드']==851690]))
print(len(trade_df[trade_df['품목코드']==847982]))
print(len(trade_df[trade_df['품목코드']==382499]))
print(len(trade_df[trade_df['품목코드']==852852]))

# %%
# continent 컬럼을 선택합니다.
# 컬럼의 값과 조건을 비교합니다.
# 그 결과를 새로운 변수에 할당합니다.
is_asia = df['continent'] == 'Asia'

# lifeExp 컬럼을 선택합니다.
# 컬럼의 값과 조건을 비교합니다.
# 그 결과를 새로운 변수에 할당합니다.
lifeExp_greather_80 = df['lifeExp'] >= 80

# 두가지 조건를 동시에 충족하는 데이터를 필터링하여 새로운 변수에 저장합니다. (AND)
subset_df = df[is_asia & lifeExp_greather_80]

# 결과를 출력합니다.
subset_df

# %%
trade_df[trade_df['국가명']=='Kuwait'][['수입국가 간 평균 거리']].mean()
# Out:
# 수입국가 간 평균 거리    5035.583795
# dtype: float64

# %%
ex_train = trade_df[trade_df['국가명']=='Kuwait'][['수입국가 간 평균 거리']]

# %%
ex_train[ex_train['수입국가 간 평균 거리'].notnull()].mean()
# Out:
# 수입국가 간 평균 거리    5035.583795
# dtype: float64

# %%
trade_df[trade_df['수입국가 간 평균 거리'].isnull()]
# Out:
#        기준연도    품목코드  국가코드                   국가명  국가 전체 품목 수입금액  \
# 20     2017  190590   414                Kuwait    33568329846
# 62     2017  190230   414                Kuwait    33568329846
# 105    2017  190219   414                Kuwait    33568329846
# 269    2017  540769   344  China, Hong Kong SAR   589317409641
# 486    2017  210690   414                Kuwait    33568329846
# 529    2017  210390   414                Kuwait    33568329846
# 1090   2017  481890   682          Saudi Arabia   134519106951
# 3642   2017  390120    36             Australia   228441691195
# 10247  2017  600410   364                  Iran    51612276867
# 13068  2017  852692   826        United Kingdom   641332371112
# 21125  2017  382499   484                Mexico   420369113272
# 21131  2017  382499   608           Philippines   101889431966
# 21134  2017  382499   682          Saudi Arabia   134519106951
# 21136  2017  382499   702             Singapore   327709659599
# ...

# %%
trade_df[trade_df['국가명']=='Kuwait'][['수입국가 간 평균 거리']].mean()

# %%
trade_df[trade_df['국가명']=='Kuwait'][['수입국가 간 평균 거리']].fillna(trade_df[trade_df['국가명']=='Kuwait'][['수입국가 간 평균 거리']].mean())
# Out:
#        수입국가 간 평균 거리
# 20      5035.583795
# 62      5035.583795
# 105     5035.583795
# 148     5185.053438
# 190     4953.149089
# ...             ...
# 20999   4897.085247
# 21039   5004.917917
# 21080   6111.497137
# 21123   4883.941619
# 21166   5184.720709
#
# [491 rows x 1 columns]

# %%
trade_df[trade_df['국가명']=='nation'][['수입국가 간 평균 거리']].fillna(trade_df[trade_df['국가명']=='nation'][['수입국가 간 평균 거리']].mean())

# %%
trade_df[trade_df['국가명']=='Kuwait'][['수입국가 간 평균 거리']].mean()
# Out:
# 수입국가 간 평균 거리    5035.583795
# dtype: float64

# %%
trade_df[trade_df['국가명']=='New Zealand'][['수입국가 간 평균 거리']].mean()
# Out:
# 수입국가 간 평균 거리    13555.548299
# dtype: float64

# %%
trade_df[trade_df['국가명']=='New Zealand'][['수입국가 간 평균 거리']].fillna(trade_df[trade_df['국가명']=='New Zealand'][['수입국가 간 평균 거리']].mean())
# Out:
#        수입국가 간 평균 거리
# 25      13546.89001
# 67      11524.01998
# 110     12433.00957
# 153     13865.20639
# 195     13119.29740
# ...             ...
# 21004   14289.95764
# 21044   13364.39246
# 21085   13979.93076
# 21128   13648.23703
# 21171   13840.59416
#
# [500 rows x 1 columns]

# %%
trade_df[trade_df['국가명']=='Kuwait'][['수입국가 간 평균 거리']].fillna(5035.583795)

# %%
trade_df[trade_df['해당 국가 해당 품목 관세율'].isnull()]['국가명'].value_counts()
# Out:
# New Zealand             8
# Egypt                   4
# South Africa            3
# Iran                    3
# USA                     3
# Singapore               3
# Belgium                 3
# United Arab Emirates    3
# Switzerland             3
# Germany                 3
# Turkey                  3
# Guatemala               3
# Kuwait                  3
# Kazakhstan              3
# Japan                   3
# Chile                   3
# Russian Federation      3
# China, Hong Kong SAR    3
# India                   3
# Canada                  3
# Saudi Arabia            3
# Malaysia                3
# Australia               3
# Austria                 3
# Mexico                  3
# Netherlands             3
# Indonesia               3
# Peru                    3
# Poland                  3
# United Kingdom          3
# France                  3
# Italy                   3
# Viet Nam                3
# Myanmar                 3
# Spain                   3
# ...

# %%
lists = list(trade_df[trade_df['수입국가 간 평균 거리'].isnull()]['국가명'].unique())

# %%
lists
# Out:
# ['Kuwait',
#  'China, Hong Kong SAR',
#  'Saudi Arabia',
#  'Australia',
#  'Iran',
#  'United Kingdom',
#  'Mexico',
#  'Philippines',
#  'Singapore',
#  'Viet Nam',
#  'Egypt']

# %%
for nation in lists:
    trade_df[trade_df['국가명']=='{}'.format(nation)][['수입국가 간 평균 거리']].fillna(trade_df[trade_df['국가명']=='{}'.format(nation)][['수입국가 간 평균 거리']].mean())
    
#     trade_df[trade_df['국가명']=='a'][['수입국가 간 평균 거리']] = trade_df[trade_df['국가명']=='a'][['수입국가 간 평균 거리']].fillna(b)

# %%
trade_df['수입국가 간 평균 거리'].isna().sum()
# Out:
# 22

# %%
trade_df
# Out:
#        기준연도    품목코드  국가코드                   국가명  국가 전체 품목 수입금액  \
# 0      2017  190590    12               Algeria    46052990973
# 1      2017  190590    36             Australia   228441691195
# 2      2017  190590    40               Austria   166475020975
# 3      2017  190590    56               Belgium   406412223480
# 4      2017  190590    76                Brazil   150749493921
# ...     ...     ...   ...                   ...            ...
# 21184  2017  852852   784  United Arab Emirates   270954907547
# 21185  2017  852852   792                Turkey   233799651234
# 21186  2017  852852   818                 Egypt    66338749061
# 21187  2017  852852   826        United Kingdom   641332371112
# 21188  2017  852852   842                   USA  2405276626657
#
#        해당 품목 전세계 총 수입금액  해당 국가 해당 품목 관세율  수입국가 간 평균 거리             GDP  \
# 0           19480986257             30.0   3878.238437    170163165961
# ...

# %%
trade_df.isna().sum()
# Out:
# 기준연도                                0
# 품목코드                                0
# 국가코드                                0
# 국가명                                 0
# 국가 전체 품목 수입금액                       0
# 해당 품목 전세계 총 수입금액                    0
# 해당 국가 해당 품목 관세율                   129
# 수입국가 간 평균 거리                       22
# GDP                                 0
# 이전 GDP                              0
# 인구                                  0
# 공식환율                                0
# 비즈니스 용이성점수                          0
# 해당 국가와 한국과의 거리                      0
# 해당 연도 해당 국가의 해당 품목 수입금액            21
# 내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액      0
# dtype: int64

# %%
trade_df['수입국가 간 평균 거리'].isnull()

# %%
trade_df

# %%
trade_df[trade_df['해당 국가 해당 품목 관세율'].isnull()]

# %%
trade_df[trade_df['해당 국가 해당 품목 관세율'].isnull()]['품목코드'].value_counts()

# %%
trade_df[trade_df['해당 국가 해당 품목 관세율'].isnull()]['국가명']

# %%
trade_df.isna().sum()

# %%
trade_df['국가명'].unique()

# %%
trade_df['해당 국가 해당 품목 관세율'].unique()

# %%
trade_df['해당 국가 해당 품목 관세율']

# %%
test_df = pd.read_csv('Test_KOTRA_0525.csv')

# %%
test_df.columns=['기준연도', '품목코드', '국가코드', '국가명', '국가 전체 품목 수입금액', '해당 품목 전세계 총 수입금액','해당 국가 해당 품목 관세율', '수입국가 간 평균 거리','GDP', '이전 GDP', '인구', '공식환율', '비즈니스 용이성점수', '해당 국가와 한국과의 거리','해당 연도 해당 국가의 해당 품목 수입금액', '내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액']

# %%
test_df.isna().sum()
# Out:
# 기준연도                                  0
# 품목코드                                  0
# 국가코드                                  0
# 국가명                                   0
# 국가 전체 품목 수입금액                         0
# 해당 품목 전세계 총 수입금액                      0
# 해당 국가 해당 품목 관세율                     625
# 수입국가 간 평균 거리                          3
# GDP                                   0
# 이전 GDP                                0
# 인구                                    0
# 공식환율                               3488
# 비즈니스 용이성점수                            0
# 해당 국가와 한국과의 거리                        0
# 해당 연도 해당 국가의 해당 품목 수입금액               3
# 내년 해당 국가가 해당 품목을 한국으로부터 수입한 금액    21189
# dtype: int64

# %%
test_df[test_df['해당 연도 해당 국가의 해당 품목 수입금액'].isna()]['국가명'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 4714    Guatemala
# 4732     Viet Nam
# 4734        Spain
# Name: 국가명, dtype: object>
